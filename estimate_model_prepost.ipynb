# %%
# estimere model på både pre-reform og post-reform data samlet

from Model_class import ModelClass
from Model_estimation import *

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %reload_ext autoreload
# %autoreload 2

# %%
model = ModelClass()
model.par.weight = True
model.par.unobs_het = True
model.par.moments_start = 0
model.par
# Out:
# namespace(pre=namespace(w=10000,
#                         b1=4000,
#                         b2=4000,
#                         b3=1600,
#                         T1=12,
#                         T2=106,
#                         T3=110),
#           post=namespace(w=10000,
#                          b1=3500,
#                          b2=3500,
#                          b3=1600,
#                          T1=12,
#                          T2=54,
#                          T3=60),
#           w=10000,
#           b1=4000,
#           b2=4000,
#           b3=1600,
#           T1=12,
#           T2=106,
#           T3=110,
#           kappa=array([ 30.,  50., 100.]),
#           gamma=1.0,
#           delta=0.8,
#           mu=1.5,
#           type_share1=0.2,
#           type_share2=0.2,
#           kappa0=array([ 30.,  50., 100.]),
#           gamma0=1.0,
#           delta0=0.8,
#           mu0=1.1,
#           type_share1_0=0.4,
#           type_share2_0=0.3,
# ...

# %%
# plot data.pre.moments and data.post.moments side by side
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.plot(model.data.pre.moments, label="Pre-reform")
plt.title("Pre-reform moments")
plt.xlabel("Time")
plt.ylabel("Log hazard rate")
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(model.data.post.moments, label="Post-reform", color="tab:orange")
plt.title("Post-reform moments")
plt.xlabel("Time")
plt.ylabel("Log hazard rate")
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
# solve model
smm_estimate_prepost(model.par, model.sol, model.data)
# Out:
# (array([-6.90775528, -4.49250116, -3.35882099,  1.32866066,  2.14858958,
#          1.11821807, -0.22569391, -5.70812367]),
#  271.5507738486623,
#  True,
#  'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH')

# %%
# plot data.pre.moments and data.post.moments side by side
plt.figure(figsize=(10, 3))

plt.subplot(1, 2, 1)
plt.plot(model.sol.pre.moments)
plt.plot(model.data.pre.moments, linestyle = "dashed", label="Pre-reform")
plt.title("Pre-reform moments")
plt.xlabel("Time")
plt.ylabel("Log hazard rate")
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(model.sol.post.moments)
plt.plot(model.data.post.moments,  linestyle = "dashed",  label="Post-reform", color="tab:orange")
plt.title("Post-reform moments")
plt.xlabel("Time")
plt.ylabel("Log hazard rate")
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
model.print_par()
# Out:
#      Parameter  Estimated Value
# 0       kappa1           0.0010
# 1       kappa2           0.0112
# 2       kappa3           0.0348
# 3        gamma           3.7760
# 4        delta           0.8955
# 5           mu           3.0594
# 6  type_share1           0.4438
# 7  type_share2           0.0018
# 8  type_share3           0.5543
